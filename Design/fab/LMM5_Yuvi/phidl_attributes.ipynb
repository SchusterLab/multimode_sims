# %%
import phidl
import phidl.geometry as pg
from phidl import Device

# List attributes of phidl module
print("phidl module attributes:")
print(dir(phidl))

# List attributes of phidl.geometry module
print("\nphidl.geometry module attributes:")
print(dir(pg))

# List attributes of Device class
print("\nphidl.Device class attributes:")
print(dir(Device))

# Get help on Device class
print("\nDevice class help:")
help(Device)

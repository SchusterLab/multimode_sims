# %%
import numpy as np

freq = 8.051e9
T1 = 0.05e-6

q = freq*T1 * 2 * np.pi
print("q = ", q /1e6, " Million")
# Out:
# q =  0.0025292962454051423  Million

# %%
q = 4e5
freq = 7.615e9
kappa = freq/q * 2 * np.pi
print("kappa = ", kappa /1e6, " Mhz")
print("t1 = ", 1/kappa * 1e6, " us")
# Out:
# kappa =  0.11961614028543138  Mhz
# t1 =  8.360075802594634  us

# %%
freq = 7.615e9
t1_r = 0.05e-6
q_r = freq * t1_r * 2 * np.pi
print("q_r = ", q_r /1e6, " Million")

#1/q_r = 1/q_i + 1/qr1 + 1/qr2
#q_r = 1/(1/q_i + 1/(1/qr1 + 1/qr2))

kappa_r = 0.125e6
q_r_meas = freq / kappa_r * 2 * np.pi 
print("q_r_meas = ", q_r_meas /1e6, " Million")
# Out:
# q_r =  0.0023923228057086275  Million
# q_r_meas =  0.3827716489133804  Million

# %%
x = np.linspace(-2, 2, 200)
plt.plot(x, np.exp(x), label='e^x')
plt.plot(x, np.exp(-x), label='1/e^x')
plt.xlabel('x')
plt.ylabel('y')
plt.title('e^x and 1/e^x')
plt.legend()
plt.show()
